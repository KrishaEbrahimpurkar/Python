# %%
print("hello world")
# Out:
# hello world

# %%
#create a new directory
import os
new_directory = "pacakge"
os.mkdir(new_directory)
print(f"Directory {new_directory} created")
# Out:
# Directory pacakge created

# %%
#Listing files and directories
items = os.listdir(".")
print(items)
# Out:
# ['6.2 filepath.ipynb', 'destination.txt', 'example.bin', 'filehandlingquestions.ipynb', 'filehandlingsolution.ipynb', 'pacakge', 'sample.txt']

# %%
#Joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\Krisha Ebrahimpurkar\Desktop\Udemy course\6_File_Handling\folder\file.txt

# %%
path = "sample.txt"
if os.path.exists(path):
    print(f"The path {path} exist")
else:
    print(f"The path {path} does not exist")
# Out:
# The path sample.txt exist

# %%
# checking if a path is a file or directory
path = "sample.txt"
if os.path.isfile(path):
    print(f"The path is {path} is a file")
elif os.path.isdir(path):
    print(f"The path {path} is a directory")
else:
    print(f"The path {path} is neither a file nor a directory")
# Out:
# The path is sample.txt is a file

# %%
simple = 23
print(f"the word is {simple}")
# Out:
# the word is 23

# %%
#Getting the absolute path
realtive_path = "sample.txt"
absolute_path = os.path.abspath(realtive_path)
print(absolute_path)
# Out:
# c:\Users\Krisha Ebrahimpurkar\Desktop\Udemy course\6_File_Handling\sample.txt
