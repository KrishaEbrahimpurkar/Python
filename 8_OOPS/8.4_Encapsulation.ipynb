# %% [markdown]
# ## Encapsulation and Abstract
#
# encapsulation and abstraction are two fundamental principles of Object - Oriented Programming (OOP) that help in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves hiding complex implementation details and exposing only the necessary features.

# %%
#Enacpsulation with Getter and Setter Methods
### Public, protected, private variables or acces modifiers

class Person:
    def __init__(self, name, age):
        self.name = name ### public variables
        self.age = age   ### public variables

def get_name(person):
    return person.name

person = Person("Krisha", 22)
get_name(person)
# Out:
# 'Krisha'

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name ### private variables
        self.__age = age   ### private variables

def get_name(person):
    return person.__name ### will not be able to acces this as __name is a private variable

# %%
person = Person("Krisha", 22)

# %%
class Person:
    def __init__(self, name, age, gender):
        self._name = name ### protected variables( cannot acces outside class but can access from derived class)
        self._age = age   ### protected variables
        self.gender = gender

## Derived class
### Protected variables can be accessed from derived class
class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age,gender)

employee = Employee("Krisha", 22, "Female")
print(employee._name)
# Out:
# Krisha

# %%
#### Encapsulation with Getter and Setter Method
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

### Getter and setter are used to acces private variables 
    ###getter method for name 
    def get_name(self):
        return self.__name

    ## Setter Method
    def set_name(self, name):
        self.__name = name

    ###getter method for age 
    def get_age(self):
        return self.__age

    ## Setter method for age
    def set_age(self, age):
        self.__age = age
        if age > 0:
            self.__age = age
        else:
            print("Age cannot be negetive")

person = Person("Krisha", 22)

### Access and modify private variiables using getter and setter 
print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-11)
# Out:
# Krisha
# 22
# 35
# Age cannot be negetive
