# %% [markdown]
# Class and Objects
#
# Object-Oriented Programmimg (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allowsfor modelling real-world scenarios using classes and object

# %%
#A class is a blue print for creating objects. Attributes, methods
class car:
    pass

audi = car()
bmw = car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
print(bmw)

audi.windows = 4 # not proper way initialising object
print(audi.windows)
# Out:
# ...
# 4

# %%
#Instance variables and Methods
class Dog:
    #coonstructor
    def __init__(self, name,age): #if i want to define any attributes initially, we will define it here 
        self.name  = name #have to assign name to name because name assignment will be done at run time
        #self.name is instance variable
        self.age = age

#create object
dog1 = Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 = Dog("Lucy",4)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# ...
# Lucy
# 4

# %%
## Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")

dog1 = Dog("Buddy",3)
dog1.bark()
dog2 = Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
## Modelling a Bank account
## Defin a class for bank account
class BankAccount:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw (self, amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-= amount
            print(f"{amount} is withdrawn and new balance is {self.balance}")

    def get_balance(self):
        return self.balance

## create and account (craeting an object)
account = BankAccount("Krisha", 5000)
print(account.balance)
# Out:
# 5000

# %%
#Call instance method
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn and new balance is 4800

# %%
print(account.get_balance())
# Out:
# 4800
