# %% [markdown]
# **ITERATORS**
#
# Iterators are advanced Python concepts that allow for looping and memory management. Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure

# %%
my_list = [1,2,3,4,5,6]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
##Iterator (uses lazy loading)
iterator = iter(my_list) ##iter is a keyword
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
## Iterate through all the elements (everytime we execute it moves forward)(after all the elements are iterated, it gives error)
next(iterator)
# Out:
# 1

# %%
iterator = iter (my_list)

try:
    print(next(iterator))
except StopIteration:
    print("There are no more elements to iterate.")
# Out:
# 1
